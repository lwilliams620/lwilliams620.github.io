# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Sources:
#
# https://openjustice.doj.ca.gov/data
#
# https://data-openjustice.doj.ca.gov/sites/default/files/dataset/2020-07/Arrests%20Context_062119.pdf
#
# https://www.census.gov/quickfacts/CA#qf-headnote-a
#
# http://www.ebudget.ca.gov/budget/2019-20EN/#/Home
#
# http://www.ebudget.ca.gov/budget/2018-19EN/#/Home
#
# https://www.census.gov/content/census/en/search-results.html?stateGeo=none&q=california%20population%20ca&searchtype=web&page=1
#
# https://www.counties.org/data-and-research
#
# http://urbaninstitute.github.io/graphics-styleguide/

# %%
df = pd.read_csv('OnlineArrestData1980-2019.csv')

# %%
df.head()
# Out:
#    YEAR GENDER   RACE AGE_GROUP          COUNTY  VIOLENT  PROPERTY  F_DRUGOFF  \
# 0  1980   Male  Black  Under 18  Alameda County      505      1351        188
# 1  1980   Male  Black  18 to 19  Alameda County      205       465        183
# 2  1980   Male  Black  20 to 29  Alameda County      949      1593        606
# 3  1980   Male  Black  30 to 39  Alameda County      450       755        241
# 4  1980   Male  Black  40 to 69  Alameda County      172       218        117
#
#    F_SEXOFF  F_ALLOTHER  F_TOTAL  M_TOTAL  S_TOTAL
# 0        26          79     2149     2286      295
# 1         8          48      909     1333        0
# 2        27         178     3353     7974        0
# 3        18         110     1574     4876        0
# 4        11          66      584     3836        0

# %%
df.columns
# Out:
# Index(['YEAR', 'GENDER', 'RACE', 'AGE_GROUP', 'COUNTY', 'VIOLENT', 'PROPERTY',
#        'F_DRUGOFF', 'F_SEXOFF', 'F_ALLOTHER', 'F_TOTAL', 'M_TOTAL', 'S_TOTAL'],
#       dtype='object')

# %%
#df2 = df[(df['YEAR'] == 2017) | (df['YEAR'] == 2018) | (df['YEAR'] == 2019)]
df2 = df[df['YEAR'] == 2019]

# %%
df2.head()
# Out:
#        YEAR GENDER   RACE AGE_GROUP               COUNTY  VIOLENT  PROPERTY  \
# 94873  2019   Male  Black  Under 18       Alameda County      178       129
# 94874  2019   Male  Black  Under 18        Alpine County        2         0
# 94875  2019   Male  Black  Under 18         Butte County        4         4
# 94876  2019   Male  Black  Under 18     Calaveras County        0         1
# 94877  2019   Male  Black  Under 18  Contra Costa County       69        70
#
#        F_DRUGOFF  F_SEXOFF  F_ALLOTHER  F_TOTAL  M_TOTAL  S_TOTAL
# 94873          1         4          50      362      130       23
# 94874          0         0           0        2        2        0
# 94875          0         0           2       10       16        0
# 94876          0         0           0        1        3        1
# 94877          2         1          28      170      128        1

# %%
felony_columns = ['VIOLENT', 'PROPERTY', 'F_DRUGOFF', 'F_SEXOFF', 'F_ALLOTHER']
total_columns = ['F_TOTAL', 'M_TOTAL']

# %%
race_dct = {}
for i in df2['RACE'].unique():
    race_dct[i] = (df2[df2['RACE'] == i][total_columns].sum().sum() / df2[total_columns].sum().sum()) * 100
race_dct
# Out:
# {'Black': 16.035052516962814,
#  'Hispanic': 42.31027088197116,
#  'Other': 6.229191728518922,
#  'White': 35.42548487254711}

# %%
race_dct_f = {}
for i in df2['RACE'].unique():
    race_dct_f[i] = (df2[df2['RACE'] == i]['F_TOTAL'].sum().sum() / df2['F_TOTAL'].sum().sum()) * 100
race_dct_f
# Out:
# {'Black': 20.653199731524417,
#  'Hispanic': 42.721347556633695,
#  'Other': 6.238309557798909,
#  'White': 30.387143154042977}

# %%
race_dct_m = {}
for i in df2['RACE'].unique():
    race_dct_m[i] = (df2[df2['RACE'] == i]['M_TOTAL'].sum().sum() / df2['M_TOTAL'].sum().sum()) * 100
race_dct_m
# Out:
# {'Black': 14.246968561689375,
#  'Hispanic': 42.1511075698893,
#  'Other': 6.225661428707114,
#  'White': 37.37626243971421}

# %%
age_dct = {}
for i in df2['AGE_GROUP'].unique():
    age_dct[i] = (df2[df2['AGE_GROUP'] == i][total_columns].sum().sum() / df2[total_columns].sum().sum()) * 100
age_dct
# Out:
# {'Under 18': 3.7205498471326073,
#  '18 to 19': 3.2343221769457906,
#  '20 to 29': 31.43048694089286,
#  '30 to 39': 29.341790569294336,
#  '40 to 69': 31.684394212435752,
#  '70 and over': 0.5884562532986548}

# %%
race_age_dct = {}
for i in df2['RACE'].unique():
    for j in df2['AGE_GROUP'].unique():
        race_age_dct[i + ' ' + j] = (df2[(df2['RACE'] == i) & (df2['AGE_GROUP'] == j)][total_columns].sum().sum() / df2[total_columns].sum().sum()) * 100
race_age_dct
# Out:
# {'Black Under 18': 0.7997603571819146,
#  'Black 18 to 19': 0.6236419051604037,
#  'Black 20 to 29': 5.077004274581219,
#  'Black 30 to 39': 4.284946722266336,
#  'Black 40 to 69': 5.17229082367709,
#  'Black 70 and over': 0.07740843409584762,
#  'Hispanic Under 18': 1.973724876731348,
#  'Hispanic 18 to 19': 1.7344624440714556,
#  'Hispanic 20 to 29': 15.608545358584585,
#  'Hispanic 30 to 39': 12.560041462011384,
#  'Hispanic 40 to 69': 10.315957644082866,
#  'Hispanic 70 and over': 0.11753909648951802,
#  'Other Under 18': 0.22480778648966063,
#  'Other 18 to 19': 0.19570830143643045,
#  'Other 20 to 29': 1.808162120268362,
#  'Other 30 to 39': 1.8773922677152624,
#  'Other 40 to 69': 2.0653977642846613,
#  'Other 70 and over': 0.05772348832454485,
#  'White Under 18': 0.7222568267296838,
#  'White 18 to 19': 0.6805095262775007,
#  'White 20 to 29': 8.936775187458693,
#  'White 30 to 39': 10.619410117301356,
#  'White 40 to 69': 14.130747980391131,
#  'White 70 and over': 0.33578523438874436}

# %%
#make it so percents are per group instead of total
race_age_dct_grp = {}
for i in df2['RACE'].unique():
    for j in df2['AGE_GROUP'].unique():
        race_age_dct_grp[i + ' ' + j] = (df2[(df2['RACE'] == i) & (df2['AGE_GROUP'] == j)][total_columns].sum().sum() / df2[df2['RACE'] == i][total_columns].sum().sum()) * 100
race_age_dct_grp
# Out:
# {'Black Under 18': 4.987575540122999,
#  'Black 18 to 19': 3.8892414259365786,
#  'Black 20 to 29': 31.661912358630996,
#  'Black 30 to 39': 26.72237410967922,
#  'Black 40 to 69': 32.25615144200831,
#  'Black 70 and over': 0.48274512362189315,
#  'Hispanic Under 18': 4.664883574575204,
#  'Hispanic 18 to 19': 4.09938865414007,
#  'Hispanic 20 to 29': 36.89067697563607,
#  'Hispanic 30 to 39': 29.685561449249303,
#  'Hispanic 40 to 69': 24.381686595342984,
#  'Hispanic 70 and over': 0.2778027510563697,
#  'Other Under 18': 3.6089399120664387,
#  'Other 18 to 19': 3.141792867611138,
#  'Other 20 to 29': 29.027234978016608,
#  'Other 30 to 39': 30.138617489008308,
#  'Other 40 to 69': 33.15675378602834,
#  'Other 70 and over': 0.9266609672691745,
#  'White Under 18': 2.0388057618073563,
#  'White 18 to 19': 1.9209603728101963,
#  'White 20 to 29': 25.22696646104123,
#  'White 30 to 39': 29.976753050826527,
#  'White 40 to 69': 39.888650871626375,
#  'White 70 and over': 0.9478634818883179}

# %%
felony_dct = {}
for i in felony_columns:
    felony_dct[i] = (df2[i].sum() / df2[felony_columns].sum().sum()) * 100
felony_dct
# Out:
# {'VIOLENT': 37.063599412624484,
#  'PROPERTY': 23.289575447430913,
#  'F_DRUGOFF': 9.294433901515797,
#  'F_SEXOFF': 1.8408294123859914,
#  'F_ALLOTHER': 28.511561826042815}

# %%
black_felony_dct = {}
for i in felony_columns:
    black_felony_dct[i] = (df2[df2['RACE'] == 'Black'][i].sum() / df2[df2['RACE'] == 'Black'][felony_columns].sum().sum()) * 100
black_felony_dct
# Out:
# {'VIOLENT': 41.26923901746977,
#  'PROPERTY': 22.664511126874412,
#  'F_DRUGOFF': 6.443524307560336,
#  'F_SEXOFF': 1.6595456869958263,
#  'F_ALLOTHER': 27.963179861099658}

# %%
race_arrest_dct = {}
for i in df2['RACE'].unique():
    for j in total_columns:
        race_arrest_dct[i + ' ' + j] = (df2[df2['RACE'] == i][j].sum()  / df2[df2['RACE'] == i][total_columns].sum().sum()) * 100
race_arrest_dct
# Out:
# {'Black F_TOTAL': 35.9502784383729,
#  'Black M_TOTAL': 64.04972156162711,
#  'Hispanic F_TOTAL': 28.18281938325991,
#  'Hispanic M_TOTAL': 71.81718061674009,
#  'Other F_TOTAL': 27.95249145090376,
#  'Other M_TOTAL': 72.04750854909624,
#  'White F_TOTAL': 23.94194168398108,
#  'White M_TOTAL': 76.05805831601891}

# %%
white_felony_dct = {}
for i in felony_columns:
    white_felony_dct[i] = (df2[df2['RACE'] == 'White'][i].sum() / df2[df2['RACE'] == 'White'][felony_columns].sum().sum()) * 100
white_felony_dct
# Out:
# {'VIOLENT': 33.09040352509839,
#  'PROPERTY': 24.544506609559473,
#  'F_DRUGOFF': 10.855598784603481,
#  'F_SEXOFF': 1.7547006917893464,
#  'F_ALLOTHER': 29.75479038894931}

# %%
len(df2['COUNTY'].unique())
# Out:
# 58

# %%
df2['F_TOTAL'].sum() / df2[total_columns].sum().sum()
# Out:
# 0.2791163646564882

# %%
df2['A_TOTAL'] = df2['F_TOTAL'] + df2['M_TOTAL']
# Out:
# c:\users\l\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.groupby('COUNTY').sum()['A_TOTAL']
# Out:
# COUNTY
# Alameda County             37370
# Alpine County                 74
# Amador County               1067
# Butte County               10055
# Calaveras County            1098
# Colusa County                949
# Contra Costa County        24565
# Del Norte County            1652
# El Dorado County            4433
# Fresno County              31493
# Glenn County                1326
# Humboldt County             7104
# Imperial County             5303
# Inyo County                  775
# Kern County                34942
# Kings County                7401
# Lake County                 3599
# Lassen County                811
# Los Angeles County        247206
# Madera County               5592
# Marin County                5881
# Mariposa County              698
# Mendocino County            4364
# Merced County              10138
# Modoc County                 434
# Mono County                  328
# Monterey County            12081
# Napa County                 4109
# Nevada County               2784
# Orange County              82500
# Placer County               8978
# Plumas County                766
# Riverside County           43756
# Sacramento County          35898
# San Benito County           1632
# San Bernardino County      65659
# San Diego County           84790
# San Francisco County       15617
# San Joaquin County         20200
# San Luis Obispo County      9891
# San Mateo County           17129
# Santa Barbara County       16100
# Santa Clara County         36234
# Santa Cruz County          10427
# Shasta County               8360
# Sierra County                 90
# Siskiyou County             2139
# Solano County              12336
# Sonoma County              16158
# Stanislaus County          19726
# Sutter County               4436
# Tehama County               2526
# Trinity County               473
# Tulare County              22415
# Tuolumne County             2935
# Ventura County             33415
# Yolo County                 6174
# Yuba County                 3173
# Name: A_TOTAL, dtype: int64

# %%
c_df = pd.read_csv('countiespop.csv', thousands=',')
c_df['County'] += ' County'
c_df = c_df.set_index('County')

# %%
c_df['Population (January 2019)']
# Out:
# County
# Alameda County             1669301
# Alpine County                 1162
# Amador County                38294
# Butte County                226466
# Calaveras County             45117
# Colusa County                22117
# Contra Costa County        1155879
# Del Norte County             27401
# El Dorado County            191848
# Fresno County              1018241
# Glenn County                 29132
# Humboldt County             135333
# Imperial County             190266
# Inyo County                  18593
# Kern County                 916464
# Kings County                153710
# Lake County                  65071
# Lassen County                30150
# Los Angeles County        10253716
# Madera County               159536
# Marin County                262879
# Mariposa County              18068
# Mendocino County             89009
# Merced County               282928
# Modoc County                  9602
# Mono County                  13616
# Monterey County             445414
# Napa County                 140779
# Nevada County                98904
# Orange County              3222498
# Placer County               396691
# Plumas County                19779
# Riverside County           2440124
# Sacramento County          1546174
# San Benito County            62296
# San Bernardino County      2192203
# San Diego County           3351786
# San Francisco County        883869
# San Joaquin County          770385
# San Luis Obispo County      280393
# San Mateo County            774485
# Santa Barbara County        454593
# Santa Clara County         1954286
# Santa Cruz County           274871
# Shasta County               178773
# Sierra County                 3213
# Siskiyou County              44584
# Solano County               441307
# Sonoma County               500675
# Stanislaus County           558972
# Sutter County                97490
# Tehama County                64387
# Trinity County               13688
# Tulare County               479112
# Tuolumne County              54590
# Ventura County              856598
# Yolo County                 222581
# Yuba County                  77916
# Name: Population (January 2019), dtype: int64

# %%
np.round((df2.groupby('COUNTY').sum()['A_TOTAL'] / c_df['Population (January 2019)']) * 100000)
# Out:
# COUNTY
# Alameda County            2239.0
# Alpine County             6368.0
# Amador County             2786.0
# Butte County              4440.0
# Calaveras County          2434.0
# Colusa County             4291.0
# Contra Costa County       2125.0
# Del Norte County          6029.0
# El Dorado County          2311.0
# Fresno County             3093.0
# Glenn County              4552.0
# Humboldt County           5249.0
# Imperial County           2787.0
# Inyo County               4168.0
# Kern County               3813.0
# Kings County              4815.0
# Lake County               5531.0
# Lassen County             2690.0
# Los Angeles County        2411.0
# Madera County             3505.0
# Marin County              2237.0
# Mariposa County           3863.0
# Mendocino County          4903.0
# Merced County             3583.0
# Modoc County              4520.0
# Mono County               2409.0
# Monterey County           2712.0
# Napa County               2919.0
# Nevada County             2815.0
# Orange County             2560.0
# Placer County             2263.0
# Plumas County             3873.0
# Riverside County          1793.0
# Sacramento County         2322.0
# San Benito County         2620.0
# San Bernardino County     2995.0
# San Diego County          2530.0
# San Francisco County      1767.0
# San Joaquin County        2622.0
# San Luis Obispo County    3528.0
# San Mateo County          2212.0
# Santa Barbara County      3542.0
# Santa Clara County        1854.0
# Santa Cruz County         3793.0
# Shasta County             4676.0
# Sierra County             2801.0
# Siskiyou County           4798.0
# Solano County             2795.0
# Sonoma County             3227.0
# Stanislaus County         3529.0
# Sutter County             4550.0
# Tehama County             3923.0
# Trinity County            3456.0
# Tulare County             4678.0
# Tuolumne County           5376.0
# Ventura County            3901.0
# Yolo County               2774.0
# Yuba County               4072.0
# dtype: float64

# %%
race_arrest_dct2 = {}
for i in df2['RACE'].unique():
    for j in felony_columns:
        race_arrest_dct2[i + ' ' + j] = (df2[df2['RACE'] == i][j].sum()  / df2[df2['RACE'] == i][felony_columns].sum().sum()) * 100
race_arrest_dct2
# Out:
# {'Black VIOLENT': 41.26923901746977,
#  'Black PROPERTY': 22.664511126874412,
#  'Black F_DRUGOFF': 6.443524307560336,
#  'Black F_SEXOFF': 1.6595456869958263,
#  'Black F_ALLOTHER': 27.963179861099658,
#  'Hispanic VIOLENT': 37.414168480991464,
#  'Hispanic PROPERTY': 22.795894442184846,
#  'Hispanic F_DRUGOFF': 9.558102256142785,
#  'Hispanic F_SEXOFF': 1.9682433348485937,
#  'Hispanic F_ALLOTHER': 28.26359148583232,
#  'Other VIOLENT': 40.09284543965047,
#  'Other PROPERTY': 22.626979792463136,
#  'Other F_DRUGOFF': 9.322774440196614,
#  'Other F_SEXOFF': 1.9879847078099397,
#  'Other F_ALLOTHER': 25.96941561987985,
#  'White VIOLENT': 33.09040352509839,
#  'White PROPERTY': 24.544506609559473,
#  'White F_DRUGOFF': 10.855598784603481,
#  'White F_SEXOFF': 1.7547006917893464,
#  'White F_ALLOTHER': 29.75479038894931}

# %%
non_black_felony_dct = {}
for i in felony_columns:
    non_black_felony_dct[i] = (df2[df2['RACE'] != 'Black'][i].sum() / df2[df2['RACE'] != 'Black'][felony_columns].sum().sum()) * 100
non_black_felony_dct
# Out:
# {'VIOLENT': 35.96891236205934,
#  'PROPERTY': 23.45227360556486,
#  'F_DRUGOFF': 10.036497917471769,
#  'F_SEXOFF': 1.888015801451329,
#  'F_ALLOTHER': 28.6543003134527}

# %%
x = np.round((df2.groupby('COUNTY').sum()['A_TOTAL'] / c_df['Population (January 2019)']) * 100000).values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
np.quantile(x, 0.2)
# Out:
# 2420.2

# %%
np.quantile(x, 0.4)
# Out:
# 2799.8

# %%
np.quantile(x, 0.6)
# Out:
# 3624.999999999999

# %%
np.quantile(x, 0.8)
# Out:
# 4538.0

# %%
np.quantile(x, 1)
# Out:
# 6368.0

# %%
race_arrest_dct = {}
for i in df2['RACE'].unique():
    for j in total_columns:
        race_arrest_dct[i + ' ' + j] = (df2[df2['RACE'] == i][j].sum()  / df2[df2['RACE'] == i][total_columns].sum().sum()) * 100
race_arrest_dct
# Out:
# {'Black F_TOTAL': 35.9502784383729,
#  'Black M_TOTAL': 64.04972156162711,
#  'Hispanic F_TOTAL': 28.18281938325991,
#  'Hispanic M_TOTAL': 71.81718061674009,
#  'Other F_TOTAL': 27.95249145090376,
#  'Other M_TOTAL': 72.04750854909624,
#  'White F_TOTAL': 23.94194168398108,
#  'White M_TOTAL': 76.05805831601891}

# %%
non_black_felony_arrest_dct = {}
for i in total_columns:
    non_black_felony_arrest_dct[i] = (df2[df2['RACE'] != 'Black'][total_columns].sum() / df2[df2['RACE'] != 'Black'][total_columns].sum().sum()) * 100
non_black_felony_arrest_dct
# Out:
# {'F_TOTAL': F_TOTAL    26.376471
#  M_TOTAL    73.623529
#  dtype: float64, 'M_TOTAL': F_TOTAL    26.376471
#  M_TOTAL    73.623529
#  dtype: float64}

# %%
idk = df2.groupby('COUNTY')[['VIOLENT', 'PROPERTY', 'F_DRUGOFF', 'F_SEXOFF', 'F_ALLOTHER', 'F_TOTAL', 'M_TOTAL', 'A_TOTAL']].sum()

# %%
idk.to_csv('countydata.csv')

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df2.groupby(['COUNTY', 'RACE'])[['VIOLENT', 'PROPERTY', 'F_DRUGOFF', 'F_SEXOFF', 'F_ALLOTHER', 'F_TOTAL', 'M_TOTAL', 'A_TOTAL']].sum()
# Out:
#                                  VIOLENT  PROPERTY  F_DRUGOFF  F_SEXOFF  \
# COUNTY                 RACE
# Alameda County         Black        1762      1406        279        57
#                        Hispanic      991       777        233        46
#                        Other         467       298        110        22
#                        White         633       591        218        35
# Alpine County          Black           2         0          0         0
#                        Hispanic        0         0          0         0
#                        Other           3         3          1         1
#                        White           6         2          2         0
# Amador County          Black           2         3          2         0
#                        Hispanic        6         5          4         0
#                        Other           7         3          5         0
#                        White          78        33         22         0
# Butte County           Black          85        21         17         6
#                        Hispanic       95        42         36         7
#                        Other          31        19         17         6
#                        White         484       363        198        34
# Calaveras County       Black           3         2          1         0
#                        Hispanic       12         4         12         2
#                        Other           5         2         17         0
#                        White         114        24         34         8
# Colusa County          Black           0         5          0         0
#                        Hispanic       38        12          2         1
#                        Other           3         2          2         0
#                        White          18        11          7         1
# Contra Costa County    Black        1135      1060        250        59
#                        Hispanic      752       665        215        49
#                        Other         223       189         46        14
#                        White         612       902        292        52
# Del Norte County       Black           0         0          0         0
#                        Hispanic        7         1          0         0
#                        Other          26        11          3         0
#                        White          95        40         17         6
# El Dorado County       Black          18        11          3         0
#                        Hispanic       64        29         17         6
#                        Other          17        15          5         0
#                        White         425       191         70        21
# Fresno County          Black         576       175         45        25
#                        Hispanic     2100       796        249       119
#                        Other         201        82         19         6
#                        White         594       366         90        44
# Glenn County           Black           1         1          0         0
#                        Hispanic       35        15          7         6
#                        Other           7         2          0         0
#                        White          55        27         14         6
# Humboldt County        Black          50        19         14         8
# San Diego County       Black        1732       654        275        93
#                        Hispanic     3236      1509        770        84
#                        Other         530       249        104        22
#                        White        3080      1687        889       119
# San Francisco County   Black         745       433        119        23
#                        Hispanic       15         9          8         1
#                        Other         332       109         76        15
#                        White         902       443        370        35
# San Joaquin County     Black         853       263         79        33
#                        Hispanic     1125       450        240        69
#                        Other         226        88         41        21
#                        White         700       449        178        57
# San Luis Obispo County Black          41        18          6         8
#                        Hispanic      150        83         27        13
#                        Other          25         7          6         2
#                        White         367       204         69        15
# San Mateo County       Black         216       230         36        13
#                        Hispanic      648       303         94        50
#                        Other         290       150         37        17
#                        White         337       219         74        12
# Santa Barbara County   Black         100        51         26         9
#                        Hispanic      658       355        220        32
#                        Other          59        21         15         1
#                        White         391       242        205        11
# Santa Clara County     Black         540       421        109        52
#                        Hispanic     2247      1383        466       177
#                        Other         648       287        106        43
#                        White         853       596        238        74
# Santa Cruz County      Black          44        31          8         3
#                        Hispanic      323       150         73        22
#                        Other          32         6          6         3
#                        White         357       266         93        12
# Shasta County          Black          53        17          9         4
#                        Hispanic       62        39         11         1
#                        Other          59        35         25         4
#                        White         405       358        178        14
# Sierra County          Black           0         0          0         0
#                        Hispanic        0         0          0         0
#                        Other           2         1          0         0
#                        White          10         5          1         2
# Siskiyou County        Black          11         6          3         0
#                        Hispanic        6         3          7         1
#                        Other          23         6          7         1
#                        White         126        54         27         3
# Solano County          Black         507       327        103        26
#                        Hispanic      308       144         63        10
#                        Other          97        50         11         8
#                        White         367       284        127        22
# Sonoma County          Black         119        89         23         7
#                        Hispanic      540       166         88        28
#                        Other         102        27         10         5
#                        White         784       388         99        47
# Stanislaus County      Black         323       112         15        18
#                        Hispanic     1055       407        124        50
#                        Other         123        45         32         1
#                        White         879       522        143        56
# Sutter County          Black          48        22          4         1
#                        Hispanic      128        51         16         7
#                        Other          39        17          2         3
#                        White         194       162         31         8
# Tehama County          Black          13         0          0         1
#                        Hispanic       30        19         10         4
#                        Other           6         1          4         1
#                        White         135        99         44        14
# Trinity County         Black           1         0          1         0
#                        Hispanic        0         0          4         0
#                        Other           2         0          3         1
#                        White          25        12         39         2
# Tulare County          Black         147        59         28         4
#                        Hispanic     1518       800        500        77
#                        Other         130        64         26        12
#                        White         440       459        214        30
# Tuolumne County        Black           4         4          3         0
#                        Hispanic       23        18         19         2
#                        Other          11         6          5         0
#                        White         155        97         81        15
# Ventura County         Black         165       157         30        10
#                        Hispanic     1163       729        410        46
#                        Other          62        48         21         5
#                        White         700       453        260        22
# Yolo County            Black         114        60         15         3
#                        Hispanic      222       114         54        12
#                        Other          28        23         11         6
#                        White         189       182         57         8
# Yuba County            Black          57        15         15         2
#                        Hispanic       87        24         28         5
#                        Other          27        10          3         2
#                        White         195       136        111        10
#
#                                  F_ALLOTHER  F_TOTAL  M_TOTAL  A_TOTAL
# COUNTY                 RACE
# Alameda County         Black           1200     4704     8258    12962
#                        Hispanic         712     2759     7978    10737
#                        Other            221     1118     2993     4111
#                        White            522     1999     7561     9560
# Alpine County          Black              0        2        3        5
#                        Hispanic         276      801     1961     2762
#                        Other             93      259      661      920
#                        White            403     1203     3265     4468
# Sonoma County          Black             81      319      895     1214
#                        Hispanic         306     1128     3492     4620
#                        Other             67      211      546      757
#                        White            596     1914     7653     9567
# Stanislaus County      Black            201      669     1200     1869
#                        Hispanic         741     2377     5219     7596
#                        Other             84      285      613      898
#                        White            787     2387     6976     9363
# Sutter County          Black             34      109      234      343
#                        Hispanic          91      293      849     1142
#                        Other             30       91      262      353
#                        White            226      621     1977     2598
# Tehama County          Black              4       18       39       57
#                        Hispanic          37      100      399      499
#                        Other              8       20       88      108
#                        White            128      420     1442     1862
# Trinity County         Black              0        2        1        3
#                        Hispanic           2        6       17       23
#                        Other              1        7       12       19
#                        White             46      124      304      428
# Tulare County          Black            100      338      780     1118
#                        Hispanic        1246     4141     9654    13795
#                        Other             86      318      876     1194
#                        White            520     1663     4645     6308
# Tuolumne County        Black             11       22       33       55
#                        Hispanic          48      110      205      315
#                        Other              6       28       63       91
#                        White            305      653     1821     2474
# Ventura County         Black            151      513     1244     1757
#                        Hispanic        1409     3757    14403    18160
#                        Other             67      203      690      893
#                        White            711     2146    10459    12605
# Yolo County            Black             96      288      571      859
#                        Hispanic         169      571     1516     2087
#                        Other             28       96      293      389
#                        White            228      664     2175     2839
# Yuba County            Black             16      105      176      281
#                        Hispanic          56      200      417      617
#                        Other             13       55      194      249
#                        White            135      587     1439     2026

# %%
df2.groupby('RACE')[['VIOLENT', 'PROPERTY', 'F_DRUGOFF', 'F_SEXOFF', 'F_ALLOTHER', 'F_TOTAL', 'M_TOTAL', 'A_TOTAL']].sum()
# Out:
#           VIOLENT  PROPERTY  F_DRUGOFF  F_SEXOFF  F_ALLOTHER  F_TOTAL  \
# RACE
# Black       25017     13739       3906      1006       16951    60619
# Hispanic    46914     28584      11985      2468       35440   125391
# Other        7341      4143       1707       364        4755    18310
# White       29513     21891       9682      1565       26538    89189
#
#           M_TOTAL  A_TOTAL
# RACE
# Black      108000   168619
# Hispanic   319529   444920
# Other       47194    65504
# White      283333   372522

# %%
(c_df['Race/Ethnicity: Black (2019)'] / c_df['Population (January 2019)']) * 100
# Out:
# County
# Alameda County            11.560348
# Alpine County              0.086059
# Amador County              2.674048
# Butte County               1.618786
# Calaveras County           0.822306
# Colusa County              0.750554
# Contra Costa County        8.983812
# Del Norte County           3.233459
# El Dorado County           0.719319
# Fresno County              4.867414
# Glenn County               0.689963
# Humboldt County            1.190397
# Imperial County            2.461291
# Inyo County                0.629269
# Kern County                5.379371
# Kings County               6.350921
# Lake County                1.810330
# Lassen County              8.218905
# Los Angeles County         8.117594
# Madera County              3.141611
# Marin County               2.673093
# Mariposa County            0.763781
# Mendocino County           0.687571
# Merced County              3.418891
# Modoc County               0.781087
# Mono County                0.315805
# Monterey County            2.520352
# Napa County                1.803536
# Nevada County              0.413532
# Orange County              1.530800
# Placer County              1.295215
# Plumas County              0.960615
# Riverside County           6.016539
# Sacramento County         10.012715
# San Benito County          0.744831
# San Bernardino County      8.443880
# San Diego County           4.820654
# San Francisco County       5.277592
# San Joaquin County         7.320496
# San Luis Obispo County     1.880931
# San Mateo County           2.561573
# Santa Barbara County       1.742438
# Santa Clara County         2.398165
# Santa Cruz County          0.914611
# Shasta County              0.940858
# Sierra County              0.186741
# Siskiyou County            1.240355
# Solano County             14.140270
# Sonoma County              1.546912
# Stanislaus County          2.626250
# Sutter County              1.905836
# Tehama County              0.582416
# Trinity County             0.379895
# Tulare County              1.229775
# Tuolumne County            1.813519
# Ventura County             1.589777
# Yolo County                2.451692
# Yuba County                2.987833
# dtype: float64

# %%
np.round(((df2[df2['RACE'] == 'Other'].groupby('COUNTY').sum()['A_TOTAL'] / df2.groupby('COUNTY').sum()['A_TOTAL']) * 100).values, 1)
# Out:
# array([11. , 36.5,  7.6,  4.8,  6.2,  7.3,  7.3, 15.7,  4.4,  5.7,  6.3,
#        10.8,  2.8, 31.1,  5.2,  4.7,  8.1, 10. ,  4.9,  3.1,  6.4,  7.6,
#        11.1,  3.8, 15.7, 10.7,  3.5,  4.9,  2.4,  8.4,  5.4,  7.3,  3.5,
#         8.3,  1.7,  3.8,  5.6, 14.8,  7.5,  4.4, 15.5,  3.9, 11.9,  3.6,
#         8.7, 25.6, 13.8,  7.5,  4.7,  4.6,  8. ,  4.3,  4. ,  5.3,  3.1,
#         2.7,  6.3,  7.8])

# %%
temp =np.round((df2[df2['RACE'] == 'Black'].groupby('COUNTY').sum()['A_TOTAL'] / c_df['Race/Ethnicity: Black (2019)']) * 100000).values
temp
# Out:
# array([  6717., 500000.,   3613.,  16530.,   7547.,  23494.,   7476.,
#          2596.,   9855.,   7835.,  14925.,  26505.,   5018.,   7692.,
#          9462.,   8246.,  15620.,   1332.,   6389.,   7243.,  10815.,
#          9420.,  23529.,  10090.,   1333.,  11628.,   7117.,  20481.,
#         15403.,  10288.,  15181.,  12632.,   4088.,   7104.,   6466.,
#          6745.,   8481.,  12151.,   7265.,   9499.,  13171.,  11526.,
#          9279.,  19411.,  21819.,  33333.,  15732.,   6708.,  15675.,
#         12732.,  18461.,  15200.,   5769.,  18975.,   5556.,  12902.,
#         15741.,  12070.])

# %%
np.quantile(temp, 0.25)
# Out:
# 7148.5

# %%
np.quantile(temp, 0.5)
# Out:
# 10189.0

# %%
np.quantile(temp, 0.75)
# Out:
# 15565.75

# %%
np.quantile(temp, 1)
# Out:
# 500000.0

# %%
df2[df2['RACE'] == 'Black'].groupby('COUNTY').sum()['A_TOTAL'].values.sum()
# Out:
# 168619

# %%
c_df['Population (January 2019)'].values
# Out:
# array([ 1669301,     1162,    38294,   226466,    45117,    22117,
#         1155879,    27401,   191848,  1018241,    29132,   135333,
#          190266,    18593,   916464,   153710,    65071,    30150,
#        10253716,   159536,   262879,    18068,    89009,   282928,
#            9602,    13616,   445414,   140779,    98904,  3222498,
#          396691,    19779,  2440124,  1546174,    62296,  2192203,
#         3351786,   883869,   770385,   280393,   774485,   454593,
#         1954286,   274871,   178773,     3213,    44584,   441307,
#          500675,   558972,    97490,    64387,    13688,   479112,
#           54590,   856598,   222581,    77916], dtype=int64)
